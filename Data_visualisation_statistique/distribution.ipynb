# %%
import numpy as n
import pandas as p
import matplotlib as m
import seaborn as s

# %%
df = p.read_csv('data/ibm_hr_attrition.csv')

# %%
s.distplot(df.MonthlyIncome)

# %%
df.MonthlyIncome
# Out:
# 0       5993
# 1       5130
# 2       2090
# 3       2909
# 4       3468
#         ...
# 1465    2571
# 1466    9991
# 1467    6142
# 1468    5390
# 1469    4404
# Name: MonthlyIncome, Length: 1470, dtype: int64

# %%
s.distplot(df[df['MonthlyIncome'] < 5000].MonthlyIncome)
